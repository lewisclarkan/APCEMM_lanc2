# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_dataset("mets/input9.nc", engine="netcdf4")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /usr/local/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/APCEMM/scripts/final/mets/input9.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'bffb53d0-fbc3-4afb-8f0a-6cfbc96807be']
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ...

# %%
# Convert time coordinate to numeric type for plotting

ds.coords['time'] = ds.coords['time'].astype('float')/(10**9 * 60 * 60)
ds["relative_humidity_ice"].plot(vmin=0, vmax=120)

plt.xlabel("Time (h)")
plt.show()
